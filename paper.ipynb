# %%
#==============================================================================
#    IMPORTS
#==============================================================================


#-------------------------------------------------------------------------
#    Standard Libraries
#-------------------------------------------------------------------------
import matplotlib.pyplot as plt

#-------------------------------------------------------------------------
#    Local Libraries
#-------------------------------------------------------------------------


#    kCells
#--------------------------------------------------------------------

from kCells import Node, Edge, Face, Volume


#    Complex & Grids
#--------------------------------------------------------------------

from complex import PrimalComplex2D, DualComplex2D
from complex import PrimalComplex3D, DualComplex3D


#    Tools
#--------------------------------------------------------------------
    

from tools import MyLogging
import tools.tumcolor as tc
# from tools import colorConsole as cc
# from tools import placeFigures as pf
# from tools.tikZPicture import TikZPicture3D
 
# from tools.exportLaTeX import array2bmatrix

# %%
with MyLogging('paper001'):
    n0 = Node(0,0,0,num=0)
    n1 = Node(-2.5,1,0,num=1)
    nodesA = [n0,n1]        
    e0 = Edge(n0,n1,num=0)
    ax = plt.figure().add_subplot(projection='3d')
    for n in nodesA:
        n.plotNode(ax)
    e0.plotEdge(ax)
    ax.view_init(90,-90)
# Out:
# Paper plot 001

# %%
with MyLogging('paper002'):
    n2 = Node(-1,1,0,num=2)
    nodesB = [n0,n1,n2]
    e1 = Edge(n0,n1,geometricNodes=[n2,],num=1)
    ax = plt.figure().add_subplot(projection='3d')
    for n in nodesB:
        n.plotNode(ax)
    e1.plotEdge(ax)
    ax.view_init(90,-90)
# Out:
# Paper plot 002

# %%
with MyLogging('paper003'): 
    n0 = Node(0,0,0)
    n1 = Node(1,0,0)
    n2 = Node(1.5,1,0)
    n3 = Node(0,1,0)
    n4 = Node(1,1,0)
    n5 = Node(0,-0.5,0)
    n6 = Node(1.5,-0.5,0)
    nodes = [n0,n1,n2,n3,n4,n5,n6]



    e0 = Edge(n0,n1)
    e1 = Edge(n1,n4)
    e2 = Edge(n3,n4)
    e3 = Edge(n0,n3)
    e4 = Edge(n0,n6,geometricNodes=n5)
    e5 = Edge(n6,n4,geometricNodes=n2)
    e6 = Edge(n6,n1)

    edges = [e0,e1,e2,e3,e4,e5,e6]

    fi0 = Face([e0,e1,-e2,-e3])
    fi0.category1 = 'inner'
    fb0 = Face([e4,e6,-e0])
    fb0.category1 = 'border'
    fb1 = Face([e5,-e1,-e6])
    fb1.category1 = 'border'
    faces = [fi0,fb0,fb1]

    pc = PrimalComplex2D(nodes,edges,faces)
    dc = DualComplex2D(pc)

    pc.printDualities()

    pc.useCategory = 2

    print(dc.useCategory)
    ax = plt.figure().add_subplot(projection='3d')
    pc.plotComplex(ax)
    ax.view_init(90,-90)
    
    ax = plt.figure().add_subplot(projection='3d')
    dc.plotComplex(ax)
    ax.view_init(90,-90)
# Out:
# #########
# # NODES #
# #########
# ┌──────┬─────────┬─────────┬─────────┐
# | Node | 2D dual | 1D dual | 0D dual |
# ├──────┼─────────┼─────────┼─────────┤
# | n_b0 | f^_b0   | e^_B0   | n^_0    |
# ├──────┼─────────┼─────────┼─────────┤
# | n_i0 | f^_i0   | None    | None    |
# ├──────┼─────────┼─────────┼─────────┤
# | n_b1 | f^_b1   | e^_B1   | n^_3    |
# ├──────┼─────────┼─────────┼─────────┤
# | n_b2 | f^_b2   | e^_B2   | n^_2    |
# ├──────┼─────────┼─────────┼─────────┤
# | n_B0 | None    | None    | n^_2    |
# ┕──────┴─────────┴─────────┴─────────┘
# #########
# # EDGES #
# #########
# ┌──────┬─────────┬─────────┐
# | Edge | 2D dual | 1D dual |
# ├──────┼─────────┼─────────┤
# | e_i0 | e^_i0   | n^_0    |
# ├──────┼─────────┼─────────┤
# | e_i1 | e^_i1   | n^_1    |
# ├──────┼─────────┼─────────┤
# | e_b0 | e^_b0   | n^_B0   |
# ├──────┼─────────┼─────────┤
# | e_b1 | e^_b1   | n^_B1   |
# ├──────┼─────────┼─────────┤
# | e_B0 | None    | n^_b0   |
# ├──────┼─────────┼─────────┤
# | e_B1 | None    | n^_b1   |
# ├──────┼─────────┼─────────┤
# | e_i2 | e^_i2   | n^_2    |
# ┕──────┴─────────┴─────────┘
# #########
# # FACES #
# #########
# ┌──────┬─────────┐
# | Face | 2D dual |
# ├──────┼─────────┤
# | f_i0 | n^_i0   |
# ├──────┼─────────┤
# | f_b0 | n^_b0   |
# ├──────┼─────────┤
# | f_b1 | n^_b1   |
# ┕──────┴─────────┘
# 2

# %%
with MyLogging('paper004'): 
    n0 = Node(0,0,0)
    n1 = Node(1,0,0)
    n2 = Node(1.5,0,0)
    n3 = Node(0,1,0)
    n4 = Node(1,1,0)
    n5 = Node(0,1.5,0)
    n6 = Node(1.5,1.5,0)
    n7 = Node(0,0,1)
    n8 = Node(1,0,1)
    n9 = Node(0,1,1)
    n10 = Node(1,1,1)
    n11 = Node(0,0,1.5)
    n12 = Node(1.5,0,1.5)
    n13 = Node(0,1.5,1.5)
    n14 = Node(1.5,1.5,1.5)
    nodes = [n0,n1,n2,n3,n4,n5,n6,n7,n8,n9,n10,n11,n12,n13,n14]

    e0 = Edge(n0,n1)
    e1 = Edge(n1,n2)
    e2 = Edge(n3,n4)
    e3 = Edge(n5,n6)
    e4 = Edge(n0,n3)
    e5 = Edge(n1,n4)
    e6 = Edge(n2,n6)
    e7 = Edge(n3,n5)
    e8 = Edge(n4,n6)
    e9 = Edge(n7,n8)
    e10 = Edge(n8,n10)
    e11 = Edge(n10,n9)
    e12 = Edge(n9,n7)
    e13 = Edge(n11,n12)
    e14 = Edge(n12,n14)
    e15 = Edge(n14,n13)
    e16 = Edge(n13,n11)
    e17 = Edge(n0,n7)
    e18 = Edge(n1,n8)
    e19 = Edge(n4,n10)
    e20 = Edge(n3,n9)
    e21 = Edge(n2,n12)
    e22 = Edge(n6,n14)
    e23 = Edge(n5,n13)
    e24 = Edge(n7,n11)
    e25 = Edge(n8,n12)
    e26 = Edge(n10,n14)
    e27 = Edge(n9,n13)

    edges = [e0,e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11,e12,e13,e14,e15,e16,e17,e18,e19,e20,e21,e22,e23,e24,e25,e26,e27]

    f0 = Face([e0,e5,-e2,-e4])
    f1 = Face([e1,e6,-e8,-e5])
    f2 = Face([e2,e8,-e3,-e7])
    f3 = Face([e0,e18,-e9,-e17])
    f4 = Face([e5,e19,-e10,-e18])
    f5 = Face([e2,e19,e11,-e20])
    f6 = Face([e4,e20,e12,-e17])
    f7 = Face([e9,e10,e11,e12])
    f8 = Face([e9,e25,-e13,-e24])
    f9 = Face([e1,e21,-e25,-e18])
    f10 = Face([e6,e22,-e14,-e21])
    f11 = Face([e25,e14,-e26,-e10])
    f12 = Face([e8,e22,-e26,-e19])
    f13 = Face([e3,e22,e15,-e23])
    f14 = Face([e26,e15,-e27,-e11])
    f15 = Face([e7,e23,-e27,-e20])
    f16 = Face([e27,e16,-e24,-e12])
    f17 = Face([e13,e14,e15,e16])


    faces = [f0,f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17]

    v0 = Volume([-f0,f3,f4,-f5,-f6,f7])
    v1 = Volume([-f1,-f4,f9,f10,f11,-f12])
    v2 = Volume([-f2,f5,f12,-f13,f14,-f15])
    v3 = Volume([-f7,f8,-f11,-f14,-f16,f17])

    facesForVolume = [-f7,f8,-f11,-f14,-f16,f17]

    volumes = [v0,v1,v2,v3]

    for v in [v1,v2,v3]:
        v.category1 = 'border'

    pc = PrimalComplex3D(nodes,edges,faces,volumes)
    dc = DualComplex3D(pc,
                       createNodes=True,
                       createEdges=True,
                       createFaces=True,
                       createVolumes=True)
    
    pc.printDualities()
    ax = plt.figure().add_subplot(projection='3d')
    pc.plotComplex(ax,plotFaces=True)
    ax.view_init(30,30)
    
    ax = plt.figure().add_subplot(projection='3d')
    dc.plotComplex(ax,plotFaces=True)
    ax.view_init(30,30)
# Out:
# #########
# # NODES #
# #########
# ┌──────┬─────────┬─────────┬─────────┬─────────┐
# | Node | 3D dual | 2D dual | 1D dual | 0D dual |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b0 | v^_b0   | f^_B0   | None    | n^_19   |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b1 | v^_b1   | f^_B1   | None    | n^_20   |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b2 | v^_b2   | f^_B2   | None    | n^_21   |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b3 | v^_b3   | f^_B3   | None    | n^_600  |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b4 | v^_b4   | f^_B4   | None    | n^_22   |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b5 | v^_b5   | f^_B5   | None    | n^_604  |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_b6 | v^_b6   | f^_B6   | None    | n^_605  |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_i0 | v^_i0   | None    | None    | None    |
# ├──────┼─────────┼─────────┼─────────┼─────────┤
# | n_B0 | None    | None    | None    | n^_18   |
# ┕──────┴─────────┴─────────┴─────────┴─────────┘
# #########
# # EDGES #
# #########
# ┌──────┬─────────┬─────────┬─────────┐
# | Edge | 3D dual | 2D dual | 1D dual |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b0 | f^_b0   | e^_B0   | n^_6    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b1 | f^_b1   | e^_B1   | n^_7    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b2 | f^_b2   | e^_B2   | n^_8    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b3 | f^_b3   | e^_B3   | n^_9    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b4 | f^_b4   | e^_B4   | n^_10   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_i0 | f^_i0   | None    | n^_15   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_i1 | f^_i1   | None    | n^_16   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b5 | f^_b5   | e^_B5   | n^_11   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b6 | f^_b6   | e^_B6   | n^_12   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b7 | f^_b7   | e^_B7   | n^_13   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_i2 | f^_i2   | None    | n^_17   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_b8 | f^_b8   | e^_B8   | n^_14   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_i3 | f^_i3   | None    | n^_18   |
# ├──────┼─────────┼─────────┼─────────┤
# | e_B0 | None    | e^_i3   | n^_3    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_B1 | None    | e^_i4   | n^_4    |
# ├──────┼─────────┼─────────┼─────────┤
# | e_B2 | None    | e^_i5   | n^_5    |
# ┕──────┴─────────┴─────────┴─────────┘
# #########
# # FACES #
# #########
# ┌──────┬─────────┬─────────┐
# | Face | 3D dual | 2D dual |
# ├──────┼─────────┼─────────┤
# | f_b0 | e^_b0   | n^_B0   |
# ├──────┼─────────┼─────────┤
# | f_b1 | e^_b1   | n^_B1   |
# ├──────┼─────────┼─────────┤
# | f_i0 | e^_i0   | n^_0    |
# ├──────┼─────────┼─────────┤
# | f_i1 | e^_i1   | n^_1    |
# ├──────┼─────────┼─────────┤
# | f_b2 | e^_b2   | n^_B2   |
# ├──────┼─────────┼─────────┤
# | f_i2 | e^_i2   | n^_2    |
# ├──────┼─────────┼─────────┤
# | f_i3 | e^_i3   | n^_3    |
# ├──────┼─────────┼─────────┤
# | f_i4 | e^_i4   | n^_4    |
# ├──────┼─────────┼─────────┤
# | f_i5 | e^_i5   | n^_5    |
# ├──────┼─────────┼─────────┤
# | f_B0 | None    | n^_b0   |
# ├──────┼─────────┼─────────┤
# | f_B1 | None    | n^_b1   |
# ├──────┼─────────┼─────────┤
# | f_B2 | None    | n^_b2   |
# ┕──────┴─────────┴─────────┘
# ###########
# # VOLUMES #
# ###########
# ┌────────┬─────────┐
# | Volume | 3D dual |
# ├────────┼─────────┤
# | v_i0   | n^_i0   |
# ├────────┼─────────┤
# | v_b0   | n^_b0   |
# ├────────┼─────────┤
# | v_b1   | n^_b1   |
# ├────────┼─────────┤
# | v_b2   | n^_b2   |
# ┕────────┴─────────┘

# %%
with MyLogging('paper005'):
    ax = plt.figure().add_subplot(projection='3d')
    for e in edges:
        e.plotEdge(ax,color=tc.TUMGrayMedium(),showArrow=False,showLabel=False)
    for n in pc.innerNodes:
        n.plotNode(ax)
    ax.view_init(30,120)
    
    ax = plt.figure().add_subplot(projection='3d')
    for e in edges:
        e.plotEdge(ax,color=tc.TUMGrayMedium(),showArrow=False,showLabel=False)
    for n in pc.borderNodes:
        n.plotNode(ax)
    ax.view_init(30,120)

    ax = plt.figure().add_subplot(projection='3d')
    for e in edges:
        e.plotEdge(ax,color=tc.TUMGrayMedium(),showArrow=False,showLabel=False)    
    for n in pc.additionalBorderNodes:
        n.plotNode(ax)
    ax.view_init(30,120)
